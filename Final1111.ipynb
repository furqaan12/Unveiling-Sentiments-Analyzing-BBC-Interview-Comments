# %% [markdown]
# # Importing Dependencies and Reading Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/Users/furqaankhan/Desktop/youtube_comments.csv")

# %%
data.head()
# Out:
#                                             Comments
# 0            Legacy media are at the edge of death 💀
# 1  Top g I’m going live tn unwrapping this entire...
# 2                                            Top G 🔥
# 3  Tens of thousands of comments and not one is a...
# 4  Absolutely loaded questions disgusting behavio...

# %% [markdown]
# # Wordcloud and Visualizatios

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_word_cloud(csv_file_path):
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv("/Users/furqaankhan/Desktop/youtube_comments.csv")

    # Combine all comments into a single string
    all_comments = ' '.join(df['Comments'].tolist())

    # Create a WordCloud object
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_comments)

    # Display the WordCloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

if __name__ == '__main__':
    csv_file_path = '/Users/furqaankhan/Desktop/youtube_comments.csv'  # Replace with the actual path to your CSV file
    generate_word_cloud(csv_file_path)

# %%
import pandas as pd
import csv
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import os

def extract_most_frequent_words(csv_file_path, num_words=20):
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv("/Users/furqaankhan/Desktop/youtube_comments.csv")

    # Combine all comments into a single string
    all_comments = ' '.join(df['Comments'].tolist())

    # Tokenize the comments (split into words)
    words = all_comments.split()

    # Count the frequency of each word
    word_freq = Counter(words)

    # Get the most frequent words
    most_common_words = word_freq.most_common(num_words)

    return most_common_words

def display_word_cloud(most_common_words):
    # Create a WordCloud object from the most frequent words
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(most_common_words))

    # Display the WordCloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

def save_most_frequent_words_to_file(most_common_words, output_file_path):
    with open(output_file_path, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Word', 'Frequency'])
        for word, freq in most_common_words:
            writer.writerow([word, freq])

if __name__ == '__main__':
    csv_file_path = 'youtube_comments.csv'  # Replace with the actual path to your CSV file
    most_common_words = extract_most_frequent_words(csv_file_path, num_words=20)
    
    # Display the most frequent words as a word cloud
    display_word_cloud(most_common_words)

    # Save the most frequent words to a new CSV file on the desktop
    output_file_path = os.path.join(os.path.expanduser('~'), 'Desktop', 'most_frequent_words.csv')
    save_most_frequent_words_to_file(most_common_words, output_file_path)

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: click in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from nltk) (4.64.1)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# Download the VADER lexicon data
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/furqaankhan/nltk_data...
# True

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Load the CSV file with comments
df = pd.read_csv('/Users/furqaankhan/Desktop/youtube_comments.csv')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Perform sentiment analysis for each comment
for comment in df['Comments']:
    sentiment_scores = analyzer.polarity_scores(comment)
    # sentiment_scores is a dictionary with 'compound', 'pos', 'neg', and 'neu' scores.
    # Here, 'compound' represents the overall sentiment, and 'pos' and 'neg' represent the positive and negative scores.

    print(comment)
    print('Sentiment Scores:', sentiment_scores)
# Out:
# Legacy media are at the edge of death 💀
# Sentiment Scores: {'neg': 0.358, 'neu': 0.642, 'pos': 0.0, 'compound': -0.5994}
# Top g I’m going live tn unwrapping this entire thing
# Sentiment Scores: {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.2023}
# Top G 🔥
# Sentiment Scores: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.2023}
# Tens of thousands of comments and not one is against tate. We stand with him
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Absolutely loaded questions disgusting behaviour from the bbc. The people who work for and with the bbc are sick sick human-beings who are the real monsters in this world.
# Sentiment Scores: {'neg': 0.283, 'neu': 0.717, 'pos': 0.0, 'compound': -0.8824}
# BBC is bull shi
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This was not an interview to get a genuine understanding about Tate.  It was an assault to push their own agenda and narrative.  BBC journalism is dead.
# Sentiment Scores: {'neg': 0.252, 'neu': 0.748, 'pos': 0.0, 'compound': -0.8442}
# To me this is when he became the Top G....
# Sentiment Scores: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.2023}
# I love the way he is demolishing her. She is SUCH a manipulative piece of GARBAGE!
# Sentiment Scores: {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.6696}
# bbc professional liers
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# The BBC is comedy lol
# Sentiment Scores: {'neg': 0.0, 'neu': 0.361, 'pos': 0.639, 'compound': 0.6486}
# big batty club back at it again with their BULLS*IT
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Know I&#39;m sure BBC is b****🫣😈
# Sentiment Scores: {'neg': 0.0, 'neu': 0.685, 'pos': 0.315, 'compound': 0.3182}
# BBC has absolutely garbage credibility, so glad Tate recorded the actual, raw, unedited interview.
# Sentiment Scores: {'neg': 0.0, 'neu': 0.771, 'pos': 0.229, 'compound': 0.5949}
# F*** you BBC and f*** your polishit
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# my dog stepped on a bee,<br>bugatti &amp; cigar comes with a side order of Misogyny
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Insane BBC interview..
# Sentiment Scores: {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'compound': -0.4019}
# BBC NEWS HOAX🖕🖕🖕
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# U are absolut clowns for cutting it to 12 minutes down from 38 :)
# Sentiment Scores: {'neg': 0.097, 'neu': 0.71, 'pos': 0.194, 'compound': 0.3612}
# Wow
# Sentiment Scores: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5859}
# That was Ai setting him up it was done to me thought it wa a friend of mine her exact voice and spoke to her later and it was not her . <br>All a setup , witch hunt for someone that tells the truth .
# Sentiment Scores: {'neg': 0.056, 'neu': 0.822, 'pos': 0.122, 'compound': 0.4588}
# BBC falling down now
# Sentiment Scores: {'neg': 0.348, 'neu': 0.652, 'pos': 0.0, 'compound': -0.1531}
# Funfact:<br>81k likes<br>405k dislikes
# Sentiment Scores: {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'compound': -0.4019}
# W TATE
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# BBC is absurd. This authoritative style is so 1990s. I feel like I’m watching a Michael Jackson interview. I’m glad Andrew is as smart as he is, BBC apparently proved themselves to be fake news.
# Sentiment Scores: {'neg': 0.076, 'neu': 0.715, 'pos': 0.209, 'compound': 0.6557}
# Great job, BBC ! Now lam the biggest Andrew Tates fan! Thanks so much 🙏
# Sentiment Scores: {'neg': 0.0, 'neu': 0.503, 'pos': 0.497, 'compound': 0.8715}
# Wow… she must be the worst interviewer I have ever seen
# Sentiment Scores: {'neg': 0.313, 'neu': 0.687, 'pos': 0.0, 'compound': -0.6249}
# Ahh Bbc n the reporter have Got themselves f****d up In front of a<br>Everyone by themselves
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# BBC must hate that YouTube allows comments. they wish they can find a way to control the voice of the people
# Sentiment Scores: {'neg': 0.152, 'neu': 0.738, 'pos': 0.111, 'compound': -0.25}
# I didn’t know who Andrew Tate was, but now I know how messed up bbc is,lies and manipulation of of an interview.come on ,thanks to internet you can’t do that anymore.
# Sentiment Scores: {'neg': 0.165, 'neu': 0.727, 'pos': 0.108, 'compound': -0.2617}
# I&#39;m not a big fan of Tate but if what he is saying is so damaging and these 10 and 11 year old boys have access to it, I think they&#39;re missing the real problem......
# Sentiment Scores: {'neg': 0.253, 'neu': 0.747, 'pos': 0.0, 'compound': -0.8791}
# Free Andrew rate you brain dead people!!!!
# Sentiment Scores: {'neg': 0.397, 'neu': 0.363, 'pos': 0.24, 'compound': -0.4885}
# Liar BBC
# Sentiment Scores: {'neg': 0.767, 'neu': 0.233, 'pos': 0.0, 'compound': -0.5106}
# You&#39;re all entitled to your own opinion
# Sentiment Scores: {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.2732}
# BBC is a joke
# Sentiment Scores: {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.296}
# It’s sad that there are reaction videos out there of people watching this version and fully buying into it instead of watching the unedited one.
# Sentiment Scores: {'neg': 0.114, 'neu': 0.886, 'pos': 0.0, 'compound': -0.4767}
# BBC is just like CNN… dead
# Sentiment Scores: {'neg': 0.398, 'neu': 0.37, 'pos': 0.231, 'compound': -0.4215}
# BBC sucks 🤮🤮😆😆
# Sentiment Scores: {'neg': 0.556, 'neu': 0.444, 'pos': 0.0, 'compound': -0.3612}
# I don&#39;t know if Andew made the statement, but even if he did, there is nothing illegal there. Men and woman having been using good sex to influence people since forever. I have to look more into his content. I&#39;ve only seen a little bit of it, but it seems like they want to put him in prison because of his mindset around relatonships
# Sentiment Scores: {'neg': 0.061, 'neu': 0.768, 'pos': 0.171, 'compound': 0.7897}
# BBC DO A BETTER JOB y’all 🚮🗑
# Sentiment Scores: {'neg': 0.0, 'neu': 0.579, 'pos': 0.421, 'compound': 0.5622}
# BBC is absolute garbage
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Actually the unprofessional reporter came with loaded questions. Tate won the day
# Sentiment Scores: {'neg': 0.194, 'neu': 0.588, 'pos': 0.218, 'compound': 0.1027}
# Wether he’s right or wrong is something else, but damn that journalist just got schooled
# Sentiment Scores: {'neg': 0.301, 'neu': 0.699, 'pos': 0.0, 'compound': -0.6808}
# Geeks
# Sentiment Scores: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.1027}
# Bbc is such a joke! You guys are a bunch of fuckin 🤡s
# Sentiment Scores: {'neg': 0.0, 'neu': 0.801, 'pos': 0.199, 'compound': 0.3595}
# based tate
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# BBC NEWS - What a terrible attempt at hit job on Andrew Tate.  Poor Lucy Williamson, the full unedited version is available for us all to see the real truth.  Poor Lucy Williamson flatly refused to acknowledge or listen to any point that he made . This edit does not reflect how the interview went at all.  Andrew Tate was articulate, fair and did not rise to her inflammatory attacks at him.<br> RIP BBC NEWS                     <br><br>Lucy Williamson and BBC NEWS - We are waiting for &quot;Sophie&quot;  and How does having a Bugatti and a cigar come with misogyny?
# Sentiment Scores: {'neg': 0.138, 'neu': 0.817, 'pos': 0.044, 'compound': -0.8689}
# This isn’t an interview. This is a failed interrogation. Kinda sad how most “interviews” are now basically loaded and essentially interrogations.
# Sentiment Scores: {'neg': 0.253, 'neu': 0.747, 'pos': 0.0, 'compound': -0.7275}
# Sudah kaya,ganteng,kaya dunia akhirat setelah masuk islam di putihkan semua dosa nya,enak sekali kaya dunia akhirat masuk surga.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# The BBC are braves for not closing the comments 👏👏<br>NOW we can practice our &quot;free speech&quot; in the comments 😈
# Sentiment Scores: {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.4404}
# <a href="https://youtube.com/@OSMANBZHAUSATV">https://youtube.com/@OSMANBZHAUSATV</a>
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Lucy&#39;s conduct, in this instance, is regrettably unprofessional. Additionally, the editorial decisions made by the BBC, which seemingly aim to cast Andrew in a negative light, are deeply disconcerting. However, Andrew&#39;s foresight and his team&#39;s thoroughness to record the entirety of the interview provides an enlightening counter-narrative, a move that could be lauded as an act of absolute prudence.
# Sentiment Scores: {'neg': 0.151, 'neu': 0.799, 'pos': 0.05, 'compound': -0.7717}
# Cut all the bits were the BBC looked bad aswell as when he is talking about donating to charity. Watch The Full Interview
# Sentiment Scores: {'neg': 0.197, 'neu': 0.704, 'pos': 0.099, 'compound': -0.4215}
# He absolutely destroyed her 🤣
# Sentiment Scores: {'neg': 0.538, 'neu': 0.462, 'pos': 0.0, 'compound': -0.5413}
# Women need to be protected..they need to be loved sincerely..
# Sentiment Scores: {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.5994}
# Thank you Andrew Tate❤
# Sentiment Scores: {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.3612}
# This was Disgusting by the BBC - how dare you
# Sentiment Scores: {'neg': 0.298, 'neu': 0.702, 'pos': 0.0, 'compound': -0.5267}
# God will protect him
# Sentiment Scores: {'neg': 0.0, 'neu': 0.299, 'pos': 0.701, 'compound': 0.5719}
# Good luck for Andrew tate❤
# Sentiment Scores: {'neg': 0.0, 'neu': 0.337, 'pos': 0.663, 'compound': 0.7096}
# BBC just showed us how they tried and failed to back someone into a corner and just continue to &quot;challenge him&quot; 😂😂
# Sentiment Scores: {'neg': 0.142, 'neu': 0.858, 'pos': 0.0, 'compound': -0.5106}
# And the award for the most incompetent interviewer goes tooooooo......🎉🎉🎉
# Sentiment Scores: {'neg': 0.228, 'neu': 0.537, 'pos': 0.235, 'compound': 0.0276}
# Boycott BBC ... bunch of 🤡 and child predators
# Sentiment Scores: {'neg': 0.247, 'neu': 0.753, 'pos': 0.0, 'compound': -0.3182}
# They turned the dislike counter off 😭😭😭😭😭😭
# Sentiment Scores: {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'compound': -0.3818}
# Lucy went out so sad, she needs to be fired 😭
# Sentiment Scores: {'neg': 0.487, 'neu': 0.513, 'pos': 0.0, 'compound': -0.822}
# Greatness, even in the light of fierce slander and interrogations.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Congratulations BBC, really like to see how much care you guys have to make storys for ur own entertainment and profit, was that the best professional u got to interview Tate?<br>I bet she get paid really good to say what she saying, if not she&#39;s really dumb blind citizen Jez... 🤦‍♀️ Shame
# Sentiment Scores: {'neg': 0.083, 'neu': 0.562, 'pos': 0.355, 'compound': 0.9629}
# Females automatically lose when they speak from a emotional standpoint instead of speaking fact you wonder why people can’t work cases they have emotional attachments to
# Sentiment Scores: {'neg': 0.093, 'neu': 0.724, 'pos': 0.183, 'compound': 0.1531}
# Andrew Tate is our only hope
# Sentiment Scores: {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.4404}
# You people are absolute scum. It&#39;s obvious how much of a force for good Andrew has on the world for you to want to take him down this badly. The attack on Andrew in this interview is absolutely disgusting.
# Sentiment Scores: {'neg': 0.219, 'neu': 0.693, 'pos': 0.088, 'compound': -0.803}
# Why the bbc is so retarded
# Sentiment Scores: {'neg': 0.487, 'neu': 0.513, 'pos': 0.0, 'compound': -0.6948}
# He is a fantastic muslim spreading his fake ideology.
# Sentiment Scores: {'neg': 0.244, 'neu': 0.472, 'pos': 0.283, 'compound': 0.128}
# none of these comments are against tate lmao
# Sentiment Scores: {'neg': 0.0, 'neu': 0.642, 'pos': 0.358, 'compound': 0.5994}
# It&#39;s crystal clear that the reporters are paid centinels🤮, these people are an embarrassment for society.
# Sentiment Scores: {'neg': 0.149, 'neu': 0.718, 'pos': 0.133, 'compound': -0.0772}
# This is a TERRIBLE reporter! She’s clearly bias. She is disgusting and disrespectful.
# Sentiment Scores: {'neg': 0.455, 'neu': 0.408, 'pos': 0.138, 'compound': -0.7371}
# The BBC showing their true colors. This nothing but a hit piece on a person I hate but I now hate the BBC more and have gained respect for Andrew Tate
# Sentiment Scores: {'neg': 0.241, 'neu': 0.524, 'pos': 0.235, 'compound': -0.3081}
# I don’t think this woman even believes the words coming out her mouth. She comes off extremely unlikable.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# The Full 39 min interview is out. The BBC really doctored this interview down to 12min to fit their narrative. Idk why they’re so disingenuous
# Sentiment Scores: {'neg': 0.052, 'neu': 0.855, 'pos': 0.093, 'compound': 0.2732}
# BBC is fake as hell  <br>Thanks you andrew Tate <br>Great performance
# Sentiment Scores: {'neg': 0.461, 'neu': 0.539, 'pos': 0.0, 'compound': -0.8271}
# The BBC has lost all its credibility. They should of just left this one alone
# Sentiment Scores: {'neg': 0.249, 'neu': 0.751, 'pos': 0.0, 'compound': -0.5106}
# you have to comabt bbc co-workers who are doing really bad stuff ..
# Sentiment Scores: {'neg': 0.24, 'neu': 0.76, 'pos': 0.0, 'compound': -0.5849}
# the bbc and this lady are cowards. this isn&#39;t even the whole 38 min and they couldn&#39;t even find clips of 12 min of it that doesn&#39;t show their cowardly biases. She still looks like a dumbass and they clipped less then a thirds of it lol <a href="http://www.youtube.com/results?search_query=%23freetate">#freetate</a>
# Sentiment Scores: {'neg': 0.114, 'neu': 0.789, 'pos': 0.097, 'compound': -0.2263}
# If only it showed the dislikes
# Sentiment Scores: {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'compound': -0.4019}
# Thanks Lucy now I see what Andrew Tate has to deal with when it come to media being manipulative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.4404}
# cutted video, not complete LOL
# Sentiment Scores: {'neg': 0.418, 'neu': 0.582, 'pos': 0.0, 'compound': -0.4356}
# why is the interview cut and montaged?
# Sentiment Scores: {'neg': 0.259, 'neu': 0.741, 'pos': 0.0, 'compound': -0.2732}
# BBC is evil.(knew Building 7 was going to be demo&#39;d)      Tate is great.
# Sentiment Scores: {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.6249}
# Bro the number of cuts makes her look so stupid... AND ANWSER TATE&#39;S FREAKING QUESTIONS.
# Sentiment Scores: {'neg': 0.301, 'neu': 0.63, 'pos': 0.068, 'compound': -0.6633}
# BBC is trash 😂😂
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I don&#39;t know if the women in this video or  the woman that she is speaking of are real ,but I can say that I have seen videos where he has beaten at least two women to be full on scared of him. You can find the videos on Google. In one of them, he asked her to show the bruises he has given her once she realizes that he&#39;s not asking her because he&#39;s sorry but instead cuz he wants to add more. She flees into the bathroom and hides as he grabs a cane. another one  he&#39;s laying on the bed with a woman filming on his Nightstand ,when he tells her to say something to the camera the woman does not exactly say what he told her to so he slapped the woman and held her down by her neck and hair The woman begins crying  as he screams at her telling her that she has to say exactly what the f*** he told her, someone else into the room and stops the video .These are real videos which you can find with a simple Google search.
# Sentiment Scores: {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.9655}
# TOP G🥶🥶🥶
# Sentiment Scores: {'neg': 0.0, 'neu': 0.357, 'pos': 0.643, 'compound': 0.2023}
# Andrew Tate is hated for &quot;corrupting the youth&quot; just as Socrates was. This man is a legend and hero for many boys and men.
# Sentiment Scores: {'neg': 0.146, 'neu': 0.729, 'pos': 0.125, 'compound': -0.1531}
# I didn&#39;t really pay much attention to Andrew Tate until that BBC interview. I&#39;m a huge fan now and my son thinks it&#39;s fun that his mom (me) sends him Tate videos.
# Sentiment Scores: {'neg': 0.048, 'neu': 0.73, 'pos': 0.222, 'compound': 0.7357}
# Every time I accidentally end up on a mainstream media channel I remind myself why I stopped watching mainstream media long ago. They are still super manipulative, pushing the elitist agendas of social control. But the comments are always comforting: it seems a lot of folks have woken up from &quot;matrix&quot; :)
# Sentiment Scores: {'neg': 0.057, 'neu': 0.762, 'pos': 0.181, 'compound': 0.8338}
# Women are nothing to him ever--just for sex.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# posting the partial interview to try to push your narrative and still getting ratio&#39;d. what a pathetic &quot;news&quot; outlet. How much did you corrupt fucks get paid to try to slander him?
# Sentiment Scores: {'neg': 0.19, 'neu': 0.81, 'pos': 0.0, 'compound': -0.7783}
# This lady is out of her mind geeze
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# What a psychopath
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# But he like make money of women&#39;s, how dare!! Psychopath
# Sentiment Scores: {'neg': 0.0, 'neu': 0.701, 'pos': 0.299, 'compound': 0.5905}
# Yes he said that always hitting women&#39;s he Heather woman&#39;s
# Sentiment Scores: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4019}
# His a totally a 🐖 🐷
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Narcisist and gross,his rude
# Sentiment Scores: {'neg': 0.5, 'neu': 0.5, 'pos': 0.0, 'compound': -0.4588}
# Keep that pig in Romania
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Yes lied lies lies his rude rude
# Sentiment Scores: {'neg': 0.793, 'neu': 0.056, 'pos': 0.151, 'compound': -0.8885}
# Exploiting woman&#39;s yes,pig,how can he walk free
# Sentiment Scores: {'neg': 0.259, 'neu': 0.446, 'pos': 0.295, 'compound': 0.1027}
# Ahora este desgraciado tate estara asustado y pero que le quiten sus bienes y se los den a las victimas
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Very first question is not, how was jail? Or how is ur emotional state? But have u raped anybody ?  What a shit human
# Sentiment Scores: {'neg': 0.38, 'neu': 0.578, 'pos': 0.042, 'compound': -0.9266}
# Lucy: Do you really believe, you&#39;re the most influential man on the face of the planet?<br>Andrew:  I&#39;m the most Googled person on the planet.<br><br>Lucy (again): Do you really believe, you&#39;re the most influential man on the face of the planet?<br>Andrew (again):  I&#39;m the most Googled man on the planet.<br><br>Lucy: I think we&#39;re done.  😶 <br><br>(That was the end part and it was so hilarious 😂😂)
# Sentiment Scores: {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.8817}
# She looks like a scarecrow
# Sentiment Scores: {'neg': 0.286, 'neu': 0.317, 'pos': 0.397, 'compound': 0.1779}
# He is a good role model the  BBC is racist
# Sentiment Scores: {'neg': 0.288, 'neu': 0.504, 'pos': 0.209, 'compound': -0.2732}
# good lord how i pity the men who have to live around english women like this.
# Sentiment Scores: {'neg': 0.112, 'neu': 0.612, 'pos': 0.276, 'compound': 0.4939}
# The BBC is disingenuous, she just mad. Andrew didn’t follow their agenda.
# Sentiment Scores: {'neg': 0.225, 'neu': 0.775, 'pos': 0.0, 'compound': -0.4939}
# Wow this is crazy compared to the actual video he put out with no editing manipulation…I can’t believe they even released this. It makes her, and especially the BBC, look so bad.
# Sentiment Scores: {'neg': 0.222, 'neu': 0.685, 'pos': 0.093, 'compound': -0.6476}
# Damn she cooked him
# Sentiment Scores: {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'compound': -0.4019}
# teachers are concerned that mens are thinking a mens and not identifying themselves as womens.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Compared to Tucker Carlson’s interview, this interview looks unprofessional. Instead of being an interview, the BBC seems to treat this like an argument trying to back him into a corner. Not even to mention, after watching the full 30 minute interview, some of the things Lucy Williamson said was downright laughable. I’ll give the BBC the benefit of the doubt and say they make a mistake in choosing this woman to represent them.
# Sentiment Scores: {'neg': 0.128, 'neu': 0.755, 'pos': 0.117, 'compound': -0.2323}
# Clown show from the bbc
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Andrew tate is disgusting 🤮 he has a tiny head and a huge face you can tell just by looking at him that he’s delusional.
# Sentiment Scores: {'neg': 0.132, 'neu': 0.778, 'pos': 0.089, 'compound': -0.2732}
# I love andrew tate way more now brh
# Sentiment Scores: {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.6369}
# Thank you BBC for making me realize how manipulated media can be
# Sentiment Scores: {'neg': 0.172, 'neu': 0.662, 'pos': 0.166, 'compound': -0.0258}
# Perhaps they chosen not enough skilled person for this interview but I believe that thing has been told him are not making him a Good person 😢
# Sentiment Scores: {'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.4782}
# I don&#39;t understand why she thought she was in a position of authority in his own house. I&#39;m glad he stood his ground.
# Sentiment Scores: {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.5106}
# Show everything as it is... Saw the whole video... If you dare give us the uncut edition... BBC F*CK OFF 💩💩💩
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Fake news
# Sentiment Scores: {'neg': 0.756, 'neu': 0.244, 'pos': 0.0, 'compound': -0.4767}
# BBC = BIG BULLSHIT CHANNEL
# Sentiment Scores: {'neg': 0.559, 'neu': 0.441, 'pos': 0.0, 'compound': -0.5859}
# This woman is amazing. Didn&#39;t let her be put down, and she gave him exactly what Tate LITERALLY said in streams and his stupid courses.<br>And now that so much proof got released, there is no reason for anyone to believe he&#39;s innocent. But people still refuse to believe it&#39;s ridiculous.
# Sentiment Scores: {'neg': 0.17, 'neu': 0.759, 'pos': 0.071, 'compound': -0.6956}
# Fck of bbc
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# There&#39;s only two ways: 1) Lucy really is a dumbest journalist in the world. 2) Lucy is just a set up person, to make looks Andrew like genius on her background)
# Sentiment Scores: {'neg': 0.108, 'neu': 0.816, 'pos': 0.076, 'compound': -0.2682}
# Checkmate for Andrew Tate. Andrew Tate is truly a &quot;GRANDMASTER&quot;
# Sentiment Scores: {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.4404}
# Thanks bbc for showing what a horrible news organisation you could be
# Sentiment Scores: {'neg': 0.227, 'neu': 0.584, 'pos': 0.188, 'compound': -0.1531}
# I never imagined saying this one day, but as an Arab living in an Arab country, I find that our media is more honest than yours
# Sentiment Scores: {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.7086}
# The interviewer is disgraceful and disrespectful.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# what a clusterfuck shitshow
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Fake news lol
# Sentiment Scores: {'neg': 0.449, 'neu': 0.145, 'pos': 0.406, 'compound': -0.0772}
# WHERE IS THE UNCUT VERSION OF THIS INTERVIEW?????
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Tate just ended her career 😂
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I reported this video as misinformation to YouTube, and I believe that if others who feel the same can flag it as well, we can demonstrate the need for a proper response to what the BBC has done. Thank you. :)
# Sentiment Scores: {'neg': 0.052, 'neu': 0.774, 'pos': 0.173, 'compound': 0.6486}
# It may be that Andrew Tate is being dishonest in this interview … but it is quite clear from the editing that the BBC is dishonest
# Sentiment Scores: {'neg': 0.223, 'neu': 0.662, 'pos': 0.116, 'compound': -0.5515}
# It`s all going to be sooo much fun watching the outcome of the charges. Not sure if he realizes this [ and his fans in the comment section don&#39;t seem to notice this} but she just spanked him. I don&#39;t think it went as well as he thinks.
# Sentiment Scores: {'neg': 0.061, 'neu': 0.843, 'pos': 0.096, 'compound': 0.4155}
# After reading all the comments and number of likes on them.... <br>Are you guys &quot;BBC&quot; feeling any shame?
# Sentiment Scores: {'neg': 0.137, 'neu': 0.617, 'pos': 0.247, 'compound': 0.128}
# THE BBC is DEAD &amp; has lost all journalist integrity,  <a href="about:invalid#zCSafez"></a> the BBC questioner proves to be  lazy,  disrespectful ( puts words in his mouth )  &amp; is not interested seeking the truth, but seeks to promote her narrative based on feelings &amp; not facts but made up BS.  Reminds me of the idiot women who interviewed Jordan Peterson.  <a href="about:invalid#zCSafez"></a>Pathetic. sadly I have turned OFF the BBC since they are no longer seeking truth~<a href="about:invalid#zCSafez"></a>
# Sentiment Scores: {'neg': 0.211, 'neu': 0.712, 'pos': 0.076, 'compound': -0.9031}
# ТЕЙТ ЛЕГЕНДА 💯
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# FREE TOP G
# Sentiment Scores: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6249}
# Somehow, I think the BBC is making up stuff.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# She embarrassed herself
# Sentiment Scores: {'neg': 0.556, 'neu': 0.444, 'pos': 0.0, 'compound': -0.3612}
# BBC, Bild, VICE, CNN and other western media is a machines of brainwash
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Andrew was ABSOLUTELY RIGHT when he called the reporter for being there with an agenda.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This reporter is so slimy.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sophie doesn’t exist 😂😂😂
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Bbc lol😂
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Tate absolutely owned this BBC interviewer … watch the entire interview, not this BBC edited version.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Oh damn, even this cut is looking so stupid bbc is
# Sentiment Scores: {'neg': 0.534, 'neu': 0.466, 'pos': 0.0, 'compound': -0.8468}
# Fuck bbc
# Sentiment Scores: {'neg': 0.778, 'neu': 0.222, 'pos': 0.0, 'compound': -0.5423}
# Thank You Andrew for trying to make the world a better place❤
# Sentiment Scores: {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6597}
# If Ya all dont know this video has 404K dislikes
# Sentiment Scores: {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.4019}
# The BBC is a joke and needs to be defunded !!
# Sentiment Scores: {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.4184}
# All that was said was absolute garbage. And what is even worse, BBC is so called “trustworthy” news service. How hypocritical! You know, what you claim that Tate is doing  ; you are actually doing it! So you are the LAAAASSTT person to comment about “Tate promotes immortality, sexism etc”. You do that!!! Your advertisement is full of naked women, billboards are full of nakedness, movies are full of nakedness, children amusement parks are decorated with naked women animations. And the more sexism and nakedness the better it is for your pocket! In our eyes you are truely the laaaastt person to slander Tate. You are the nation that promotes sex at the age of 12?!? How can you be such a hypocrite?
# Sentiment Scores: {'neg': 0.046, 'neu': 0.865, 'pos': 0.09, 'compound': 0.7011}
# He is Muhammad Ali in a modern era
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# BBC mindless puppets and liars
# Sentiment Scores: {'neg': 0.677, 'neu': 0.323, 'pos': 0.0, 'compound': -0.743}
# bbc, I now hate you more, you are disgrace to humanity and free speech. And this employee of yours is nasty, she did not behave as a journalist, but as a hugely biased feminist, she has to be fired because of her unprofessional tone and approach.
# Sentiment Scores: {'neg': 0.336, 'neu': 0.626, 'pos': 0.037, 'compound': -0.9529}
# Had to come back and watch this shit show.......im addicted to the BBC downfall.
# Sentiment Scores: {'neg': 0.246, 'neu': 0.754, 'pos': 0.0, 'compound': -0.6428}
# BBC I cant believe yall lol... but then again Media is always manipulated
# Sentiment Scores: {'neg': 0.236, 'neu': 0.764, 'pos': 0.0, 'compound': -0.5267}
# Always trust the God. Never trust the &quot;matrix&quot;
# Sentiment Scores: {'neg': 0.0, 'neu': 0.365, 'pos': 0.635, 'compound': 0.8271}
# However sex gender transition is totally fine with pure younger people
# Sentiment Scores: {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.2716}
# And Rotate
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Andrew tate rocks <br>the reporter shock!!!
# Sentiment Scores: {'neg': 0.41, 'neu': 0.59, 'pos': 0.0, 'compound': -0.5386}
# BBC was disgraced successfully
# Sentiment Scores: {'neg': 0.366, 'neu': 0.244, 'pos': 0.39, 'compound': 0.0516}
# Andrew Tate speaking facts
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Fuck BBC
# Sentiment Scores: {'neg': 0.778, 'neu': 0.222, 'pos': 0.0, 'compound': -0.5423}
# Why are there woman on the news? And what&#39;s worst is that they&#39;re feminists and karens  😂
# Sentiment Scores: {'neg': 0.215, 'neu': 0.785, 'pos': 0.0, 'compound': -0.6249}
# this journalist don&#39;t even know how to comb her hair.  it&#39;s like their source.  lol
# Sentiment Scores: {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.6486}
# The last part of this video is more fun than the edited interview. Correspondent asks some lady who happens to be &quot;Education Editor&quot; what she can say about what Andrew &quot;pumps out&quot; It turns out that teachers are worried about &quot;language, attitude and behaviour&quot; Andrew has. So it seems like if a free citizen is labelled by some portion of the population as bad, the publicly funded national broadcast can judge you and do hit pieces on you. They can use ongoing investigations from a non-democratic country as a jumping base, they can add jokingly said sentences as to the mix and even sprinkle childlike thought experiments  like &quot;since you drive a fast car and smoke cigars, you must be a bad person&quot; Off course this has no similarity in principal with third world countries where the semi-dictators can label you as &quot;problematic&quot; and ruin your reputation via the government power they have.
# Sentiment Scores: {'neg': 0.091, 'neu': 0.827, 'pos': 0.082, 'compound': -0.3776}
# The BBC is tarnished there&#39;s no coming back from this. It&#39;s all rubbish. I would like to hear this from these teachers mouth. I didn&#39;t see not one teacher make a comment about how bad tate is. Why because it&#39;s b.s. Don&#39;t believe everything you hear from the media. All they care about is controlling the masses. I truly believe Andrew Tate is here to save us from the corrupt. <a href="http://www.youtube.com/results?search_query=%23themessiahishere">#themessiahishere</a>
# Sentiment Scores: {'neg': 0.072, 'neu': 0.78, 'pos': 0.148, 'compound': 0.7269}
# The messiah. I said it first!
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# The messiah
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I think Lucy&#39;s gonna need a psychiatrist who&#39;s not from the UK😂😂🤘🤘
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# BBC does no research and just relies on bullshit they see and stuff they read from other people that have done the same it’s a chain of misinformation coming from misinformation this just shows that Andrew is a great person and people are trying to take him down with no reason to
# Sentiment Scores: {'neg': 0.21, 'neu': 0.722, 'pos': 0.067, 'compound': -0.7717}
# It&#39;s interesting to see news organizations literally turned into parody accounts.
# Sentiment Scores: {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
# Wow this is heavily edited to try and make Andrew look bad... they still failed. Everyone should consider watching the full unedited video that Andrew put out to see how dishonest Lucy &amp; the BBC really are. 👎
# Sentiment Scores: {'neg': 0.156, 'neu': 0.759, 'pos': 0.085, 'compound': -0.4939}
# BBC = Sky News in Australia
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# THE BBC IS FAKE NEWS
# Sentiment Scores: {'neg': 0.437, 'neu': 0.563, 'pos': 0.0, 'compound': -0.4767}
# THERE IS NO RAPE CHARGE AT ALL FAKE NEWS
# Sentiment Scores: {'neg': 0.625, 'neu': 0.375, 'pos': 0.0, 'compound': -0.875}
# We need more Andrew Tate thinkers in the world.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Bbc you guys suck lmfaooooo you cant cancel tate! Nice try…. Hahahahahaha
# Sentiment Scores: {'neg': 0.34, 'neu': 0.553, 'pos': 0.107, 'compound': -0.5837}
# <a href="https://youtu.be/6Dd5X5dnUMg">https://youtu.be/6Dd5X5dnUMg</a>
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Thanks dng media group for exposing yourself yet again for what i assume to be acting out a public humiliation fetish
# Sentiment Scores: {'neg': 0.235, 'neu': 0.648, 'pos': 0.117, 'compound': -0.4404}
# Andrew Tate is a HERO
# Sentiment Scores: {'neg': 0.0, 'neu': 0.409, 'pos': 0.591, 'compound': 0.6523}
# These comments are embarrassing. What is going on here??
# Sentiment Scores: {'neg': 0.27, 'neu': 0.73, 'pos': 0.0, 'compound': -0.4515}
# As a person who disliked Andrew Tate, after watching this and the full interview, I now have mad Respect for him
# Sentiment Scores: {'neg': 0.236, 'neu': 0.64, 'pos': 0.124, 'compound': -0.4215}
# Interview was a Joke. Tate handles every question like a gentleman. BBC should do better and send smarter journalists. <a href="http://www.youtube.com/results?search_query=%23longlivetopg">#longlivetopG</a>
# Sentiment Scores: {'neg': 0.0, 'neu': 0.586, 'pos': 0.414, 'compound': 0.8625}
# Andrew is right.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# And the way Andrew is so calm mentally managing his emotions through out the entire interview is just so crazy. It&#39;s not easy for most men especially when the attack is as gigantic as the one in front of him.
# Sentiment Scores: {'neg': 0.186, 'neu': 0.752, 'pos': 0.062, 'compound': -0.7091}
# Tate is a psychopath which deserves to be behind bars for rest of his life ye are all low life looking at something that is fake
# Sentiment Scores: {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.6369}
# Rot in jail
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# How come all his followers are like himself clueless and nonsensical very foolish root in jail tate
# Sentiment Scores: {'neg': 0.229, 'neu': 0.654, 'pos': 0.117, 'compound': -0.3384}
# This is a bunch of lies  &amp; pathetic smear against this man
# Sentiment Scores: {'neg': 0.529, 'neu': 0.471, 'pos': 0.0, 'compound': -0.8402}
# 😂 thanks
# Sentiment Scores: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4404}
# Fuck u BBC fake news. And tell that lady that interviewed andrew to get off meth it&#39;s really starting to show
# Sentiment Scores: {'neg': 0.268, 'neu': 0.732, 'pos': 0.0, 'compound': -0.765}
# The edits are deadlier than the comment section ☠
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Yea cut it off when he explain how she’s wrong
# Sentiment Scores: {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'compound': -0.6369}
# Your OWN presenter is a sexual predator.....you are ALL Hypocrites! p.s.: 402.885 Dislikes in the video
# Sentiment Scores: {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'compound': -0.4574}
# The BBC looks bad. They say Tate is responsible for England knife crime yet rappers with violent lyrics are perfectly fine. The nastiest scum of the earth work at BBC
# Sentiment Scores: {'neg': 0.314, 'neu': 0.504, 'pos': 0.182, 'compound': -0.7906}
# Fucck off BBC why are you so stupid ...you are being sponsored by someone to attack TATE for sure ...HOW MUCH DO THEY PAY YOU? to attack someone who are INNOCENT.. YOU&#39;RE SUCH A STUPID DOG WITH NO MANNER AT ALL !!!
# Sentiment Scores: {'neg': 0.363, 'neu': 0.597, 'pos': 0.04, 'compound': -0.9604}
# BBC Sucks
# Sentiment Scores: {'neg': 0.714, 'neu': 0.286, 'pos': 0.0, 'compound': -0.3612}
# I used to have a lot of respect for the BBC. It was a reliable and trustworthy organization. So i thought. This entire smear campaign being perpetrated by the BBC especially but most western media really, has made me realize that we aren&#39;t being given the whole truth in many cases but instead being presented with a ONE-sided and biased NARRATIVE and it angers me greatly!!! How can a journalist be so disingenuous. Is it not YOUR JOB TO PRESENT AN UNBIASED VIEW AND ALLOW PEOPLE TO FORM THEIR OWN OPINIONS?
# Sentiment Scores: {'neg': 0.12, 'neu': 0.772, 'pos': 0.108, 'compound': -0.3018}
# Garbage
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# BBC is TRASH!!!!!   FAKE NEWS!!!
# Sentiment Scores: {'neg': 0.556, 'neu': 0.444, 'pos': 0.0, 'compound': -0.7185}
# <a href="https://www.youtube.com/watch?v=h-JBhQqqWHY&amp;t=6m44s">6:44</a> literally avoids question
# Sentiment Scores: {'neg': 0.298, 'neu': 0.702, 'pos': 0.0, 'compound': -0.1779}
# So can ANYONE answer this please… Andrew states that he actually wasn’t charged with any crime of forcr or violence but every resource I can find says he was indicated of “rape.” Is he actually been indicted in rape or not?
# Sentiment Scores: {'neg': 0.262, 'neu': 0.738, 'pos': 0.0, 'compound': -0.9144}
# England is a failing Nation, indeed.
# Sentiment Scores: {'neg': 0.452, 'neu': 0.548, 'pos': 0.0, 'compound': -0.5106}
# Yeah lets just all unfollow bbc
# Sentiment Scores: {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.296}
# Fuck u BBC
# Sentiment Scores: {'neg': 0.778, 'neu': 0.222, 'pos': 0.0, 'compound': -0.5423}
# Top G
# Sentiment Scores: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.2023}
# He Just destroyed the BBC
# Sentiment Scores: {'neg': 0.444, 'neu': 0.556, 'pos': 0.0, 'compound': -0.4939}
# the BBC reporter is sooooooo bad - whats the point of sending this person to do a interview like this??
# Sentiment Scores: {'neg': 0.173, 'neu': 0.716, 'pos': 0.112, 'compound': -0.3313}
# FU*K BBC - MAINSTREAM MEDIA EXPOSED AND DYING SLOWLY! BBC. CNN, POLICE, THE SO CALLED &quot;AGENCIES&quot; GOVERNMENTS, WHO,... ALL UNDER 1 EVIL UMBRELLA. THANKS GOD YOUTUBE EXISTS OTHERWISE WE WOULD NEVER SEE THE OTHER SIDE OF HE MEDAL! <br><br>the only thing they really fear is that their propaganda 💩 dont get heard anymore
# Sentiment Scores: {'neg': 0.199, 'neu': 0.646, 'pos': 0.155, 'compound': -0.4486}
# I agree with Andrew most of the time and I&#39;m not even a man. I&#39;ve watched the whole vid and this doesn&#39;t even look like an interview. Media can leads to so many misunderstanding and misconceptions about a person from one sided perspective . It also shows how manipulative and biased it can get . Absolutely Horrifying
# Sentiment Scores: {'neg': 0.15, 'neu': 0.768, 'pos': 0.082, 'compound': -0.6335}
# these are the same teachers who will affirm a child&#39;s confusion over gender and accept that billy is now a girl yet refuse to inform Billy&#39;s parents......
# Sentiment Scores: {'neg': 0.152, 'neu': 0.759, 'pos': 0.09, 'compound': -0.2023}
# And also your content is disgusting really more disgusting than Andrew&#39;s allegations ☺️
# Sentiment Scores: {'neg': 0.382, 'neu': 0.618, 'pos': 0.0, 'compound': -0.7783}
# Hey BBC kindly repent before it&#39;s too late sincerely a believer named is unknown 😁♥️
# Sentiment Scores: {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.743}
# Over 1 month and we still Make fun of bbc love it
# Sentiment Scores: {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.8176}
# Fake news in Bbc
# Sentiment Scores: {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767}
# bbc is dick
# Sentiment Scores: {'neg': 0.623, 'neu': 0.377, 'pos': 0.0, 'compound': -0.5106}
# <a href="http://www.youtube.com/results?search_query=%23freetate">#FreeTate</a>
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# You got exposed 😂😂😂 bbc liars so obvious now. <br><br>You are neither news nor journalist, simple propaganda l!
# Sentiment Scores: {'neg': 0.23, 'neu': 0.69, 'pos': 0.08, 'compound': -0.5027}
# why is she so cringe? omg she is completely destroyed
# Sentiment Scores: {'neg': 0.28, 'neu': 0.72, 'pos': 0.0, 'compound': -0.5413}
# Bbc sucks <a href="http://www.youtube.com/results?search_query=%23topg">#TOPG</a>
# Sentiment Scores: {'neg': 0.455, 'neu': 0.545, 'pos': 0.0, 'compound': -0.3612}
# This is absolute rubbish by BBC!!! It&#39;s a shame!
# Sentiment Scores: {'neg': 0.379, 'neu': 0.621, 'pos': 0.0, 'compound': -0.6449}
# Nice try BBC. You ended up degrading yourself. You Clowns
# Sentiment Scores: {'neg': 0.26, 'neu': 0.548, 'pos': 0.192, 'compound': -0.25}
# Yay Andrew !!!!
# Sentiment Scores: {'neg': 0.0, 'neu': 0.305, 'pos': 0.695, 'compound': 0.6776}
# BBC قناة مخادعة ومنافقه <br>ما اثق في اخباركم ابدا
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# &quot;I genuinely believe im acting under the instruction of god&quot; says every cult leader and suicide bomber, religious terrorist every where.
# Sentiment Scores: {'neg': 0.326, 'neu': 0.674, 'pos': 0.0, 'compound': -0.8807}
# dislike, unfollow.
# Sentiment Scores: {'neg': 0.722, 'neu': 0.278, 'pos': 0.0, 'compound': -0.3818}
# GARBAGE. Vice&#39;s BANKRUPT like destiny awaits you, BBC. Shame on you. And shame on all of it&#39;s employees. After hitler lost the war, all the generals, souldiers, officers, were held accountable aswell. If you work for the BBC, don&#39;t think you&#39;re the exception.
# Sentiment Scores: {'neg': 0.296, 'neu': 0.637, 'pos': 0.067, 'compound': -0.9317}
# BBC is the most corrupt, biased, and centralized &quot;sourse&quot; of information. Actually more rather, indoctrination and extreme leftist propaganda. This people are genuinely evil.
# Sentiment Scores: {'neg': 0.295, 'neu': 0.705, 'pos': 0.0, 'compound': -0.8307}
# Burn to the ground BBC
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Bad Biased Coverage - BBC strikes again.
# Sentiment Scores: {'neg': 0.73, 'neu': 0.27, 'pos': 0.0, 'compound': -0.7964}
# The British have always been fools. They tried to ban rock n roll 😂😂😂
# Sentiment Scores: {'neg': 0.382, 'neu': 0.618, 'pos': 0.0, 'compound': -0.7783}
# Love too see that people still have common sense!! ❤
# Sentiment Scores: {'neg': 0.0, 'neu': 0.626, 'pos': 0.374, 'compound': 0.6988}
# If teachers that want to literally neuter little boys say this man is getting in the way of their programming, than this man is truly a force of good for this world, which in turn makes the BBC and the UK school system a force of evil and must be stopped immediately.
# Sentiment Scores: {'neg': 0.108, 'neu': 0.771, 'pos': 0.122, 'compound': -0.0516}
# This goes to show bbc is just basically into negative narrative, what a joke
# Sentiment Scores: {'neg': 0.219, 'neu': 0.651, 'pos': 0.13, 'compound': -0.3612}
# The media is FINALLY being exposed clearly than ever;  this interview even with all the editing is pure gold. Just confirms and shows they want us all ignorant and without any critical thinking so we just comply to everything. Much respect to this man and thanks BBC for your failed attempt to discredit him, I&#39;m sure it has and will continue helping much more people open their eyes.
# Sentiment Scores: {'neg': 0.083, 'neu': 0.715, 'pos': 0.203, 'compound': 0.8299}
# BBC proved itself and other Media as a SCAM and Fraud. Congrats BBC (MATRIX).
# Sentiment Scores: {'neg': 0.381, 'neu': 0.462, 'pos': 0.157, 'compound': -0.7034}
# Andrew actually recorded the entire interview himself and released it on YouTube. BBC just shows the manipulated parts.
# Sentiment Scores: {'neg': 0.133, 'neu': 0.867, 'pos': 0.0, 'compound': -0.3818}
# Don&#39;t like Andrew Tate. very much, but the BBC journalist is a massive fake journalist. She is an activist and not a journalist. I think Tate is innocent of a crime, but I am pretty sure he has emotionally manipulated women. All credit to Tate for standing up to this idiot.
# Sentiment Scores: {'neg': 0.251, 'neu': 0.528, 'pos': 0.221, 'compound': -0.6264}
# Horrible BBC! The full interview has so much more depth! Lucy is a horrible interviewer
# Sentiment Scores: {'neg': 0.387, 'neu': 0.613, 'pos': 0.0, 'compound': -0.8217}
# WOW! BBC edit vs unedited version.....
# Sentiment Scores: {'neg': 0.0, 'neu': 0.509, 'pos': 0.491, 'compound': 0.7027}
# BBS, this is your next failure 😂 BBS — the machine of lies 👌🏻😁
# Sentiment Scores: {'neg': 0.379, 'neu': 0.621, 'pos': 0.0, 'compound': -0.7269}
# Thank you bbc for not disabling the comment section.  matrix slave
# Sentiment Scores: {'neg': 0.0, 'neu': 0.64, 'pos': 0.36, 'compound': 0.6192}
# Wow BBC is an embarrassment anyone who watched the full Video knows
# Sentiment Scores: {'neg': 0.174, 'neu': 0.599, 'pos': 0.228, 'compound': 0.2263}
# Lost all respect for BBC after watching the Elon Musk interview and the full version of this interview. Unsubscribed.
# Sentiment Scores: {'neg': 0.103, 'neu': 0.759, 'pos': 0.138, 'compound': 0.2023}
# Nice editing BBC i almost believed Tate was a bad guy... 0.01/100
# Sentiment Scores: {'neg': 0.245, 'neu': 0.559, 'pos': 0.196, 'compound': -0.1779}
# How can the BBC attack Andrew like this. Are they quick to forget about their own past. When they were employing a real monster for decades. Jimmy Savile.
# Sentiment Scores: {'neg': 0.159, 'neu': 0.762, 'pos': 0.079, 'compound': -0.3612}
# It&#39;s crazy how he gave them the chance to have an approach with him and they attacked him, plus in he&#39;s House.....shm
# Sentiment Scores: {'neg': 0.205, 'neu': 0.72, 'pos': 0.076, 'compound': -0.5267}
# Free top g
# Sentiment Scores: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6249}
# The most famous man in the world invites you into his house, and you try to incriminate him on video for monetary gain. You should all be penalized heavily for trying to ruin a mans life. This woman should lose her job, and the rest of the BBC staff should be fired and replaced. Thank god Andrew has the entire video recorded.
# Sentiment Scores: {'neg': 0.138, 'neu': 0.752, 'pos': 0.109, 'compound': -0.4767}
# I love this man I want to be just like him
# Sentiment Scores: {'neg': 0.0, 'neu': 0.429, 'pos': 0.571, 'compound': 0.7906}
# lol this sad propaganda journalist is doing most of the talking in this version of the &quot;interview&quot;. They even turned up her microphone volume, probably for her to seem more intimidating. Haha, watch the raw full version!
# Sentiment Scores: {'neg': 0.184, 'neu': 0.686, 'pos': 0.13, 'compound': -0.3625}
# Quoting his own words still tried to lie.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Dude straight up just lying the entire time. All the racist/misogynists going wild in the comments.
# Sentiment Scores: {'neg': 0.176, 'neu': 0.725, 'pos': 0.098, 'compound': -0.3612}
# هذا الرجل اسطوره 👍🏼
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# It further proves the full form of BBC, which is Bullshit Brainwashing Corporation. <br><br>I don&#39;t even like Andrew Tate. But trying to takeway the freedom of speech, just because that goes against your agenda is just a horrible thing. Mysoginy this, mysoginy that. Anything that doesn’t pander women and serves their agenda is mysoginy. Hypocrites.<br><br>P.S. Not talking about the other BBC that Lucy and Sophie may likes. 😅
# Sentiment Scores: {'neg': 0.111, 'neu': 0.749, 'pos': 0.14, 'compound': 0.5187}
# ...
# Sentiment Scores: {'neg': 0.152, 'neu': 0.789, 'pos': 0.059, 'compound': -0.5574}
# Funniest video ever 😂😂😂
# Sentiment Scores: {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'compound': 0.5574}
# BBC shitshow :D Love Andrew :o)
# Sentiment Scores: {'neg': 0.0, 'neu': 0.209, 'pos': 0.791, 'compound': 0.9068}
# There is a real men hate these days, look at the attacks by LUCY and BBC... redefining misogyny like how they redefine genders pronouns nonsense
# Sentiment Scores: {'neg': 0.292, 'neu': 0.629, 'pos': 0.079, 'compound': -0.7783}
# No propaganda will not hold these media outlets are used to indoctrinate us on biased information Tate is the best thing to happen to man kind
# Sentiment Scores: {'neg': 0.24, 'neu': 0.551, 'pos': 0.209, 'compound': 0.2263}
# Imaginary Sophie  😂😂🤣🤣😂😂
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Wala man lang kaayos ayos yung babae dayo pa yan sa bahay ni tate hindi pa preparado.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I believe BBC proves if they showed on this video Andrew will ruin
# Sentiment Scores: {'neg': 0.257, 'neu': 0.743, 'pos': 0.0, 'compound': -0.5859}
# I didn’t believe that the matrix exist till this video
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# R.I.P. BBC
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Nobody frustrate or angry if which person doesn&#39;t do anything, he prove it wrong but why he angry
# Sentiment Scores: {'neg': 0.432, 'neu': 0.568, 'pos': 0.0, 'compound': -0.8641}
# Andrew Tate using many logical fallacies and try to dominate and hide his crime
# Sentiment Scores: {'neg': 0.379, 'neu': 0.621, 'pos': 0.0, 'compound': -0.6908}
# What a weird b......
# Sentiment Scores: {'neg': 0.459, 'neu': 0.541, 'pos': 0.0, 'compound': -0.1779}
# This is a great example of BAD JOURRNALISM, which should be taught to class and show this interview and compared both full and this edited video.
# Sentiment Scores: {'neg': 0.135, 'neu': 0.734, 'pos': 0.131, 'compound': -0.0343}
# Interviewer has failed miserably
# Sentiment Scores: {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'compound': -0.7506}
# I stand with Andrew Tate
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# <a href="https://www.youtube.com/watch?v=h-JBhQqqWHY&amp;t=1m54s">1:54</a> lol, Andrew tate never said  that. This interviewer is @*+hole.
# Sentiment Scores: {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.4215}
# Every good person not say &quot;I&#39;m a good person &quot; if he nice and good nobody can claim to bad,  Andrew Tate is fake and Fard
# Sentiment Scores: {'neg': 0.178, 'neu': 0.512, 'pos': 0.31, 'compound': 0.5994}
# Failed propaganda of BBC against the man of truth
# Sentiment Scores: {'neg': 0.39, 'neu': 0.441, 'pos': 0.169, 'compound': -0.4588}
# BBC SUCK.<br>RIP BBC.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Bbc ... ppl watched the real interview...the full 40 min .... u fucked up 😂😂😂
# Sentiment Scores: {'neg': 0.253, 'neu': 0.747, 'pos': 0.0, 'compound': -0.6597}
# 11.06.2023 12.20 - 75k Upvotes, 321k Downvotes <br><br>LMAO<br><br>You pseudo journalists will eventually understand it too. 🤢🤮🤢
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Tate has won over the manipulation and lies of BBC
# Sentiment Scores: {'neg': 0.318, 'neu': 0.446, 'pos': 0.236, 'compound': -0.0772}
# BBC got the same...^^
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Tate is the beacon of Truth in this deceiving world
# Sentiment Scores: {'neg': 0.189, 'neu': 0.63, 'pos': 0.181, 'compound': -0.0258}
# BBC needs god
# Sentiment Scores: {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.2732}
# horrible edit what a shame to the media
# Sentiment Scores: {'neg': 0.569, 'neu': 0.431, 'pos': 0.0, 'compound': -0.765}
# Not tru,VBS Lai for monei
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# The interview has 38 minutes, and you posted only 12 minutes. Where are the 25 minutes? Your channel is lying
# Sentiment Scores: {'neg': 0.152, 'neu': 0.848, 'pos': 0.0, 'compound': -0.5267}
# I watch this after watch the full interview from other channel, and the full andrew tate statement. <br>I wanna say.... congratulations for the 2,5 million views 😉
# Sentiment Scores: {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.5994}
# I m dont kare abaut dwhā monei ,bat ,when I m sy BBS ,hau Kru are ,meyc. My Angri,Fac BBS.for fals
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# These people are soulless
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# BBC are a bunch of putrid dogs <a href="http://www.youtube.com/results?search_query=%23freeandrewtate">#FreeAndrewTate</a>
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This is disgusting shameful and dishonest by the BBC, if you are really interested in this interview go watch the full and uncut interview, the attacks made on Tate and then dumb responses given
# Sentiment Scores: {'neg': 0.347, 'neu': 0.59, 'pos': 0.063, 'compound': -0.9261}
# Shaim from BBS ,Discait ,shaime from ,BBS,olee ys abaute monei,when ,a man whoate to du god for adārss.
# Sentiment Scores: {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.2732}
# He comes across as someone who can&#39;t handle a conversation. <a href="https://www.youtube.com/watch?v=h-JBhQqqWHY&amp;t=3m53s">3:53</a> He practically screams &quot;I can&#39;t handle it anymore, let&#39;s change the topic.&quot; Why does he have to run from a topic when challenged? Oooh, and he doesn&#39;t like it when she refuses to move on. This is the behaviour of a little boy who&#39;s angry at his mum for refusing to get off the topic of how he stole a cookie from the cookie jar.
# Sentiment Scores: {'neg': 0.121, 'neu': 0.848, 'pos': 0.031, 'compound': -0.7348}
# This is probably the first time in history a mainstream media interview was recorded and released by the other side.
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Another garbage interviewer with an agenda and no accurate information.  It’s ok the be a straight male and want to do better in your life.  It’s ok to believe in God and not be crucified for it.  It’s ok to say men are far more physically imposing than women, it’s the truth.  It’s ok to be against homosexuality.   We don’t have to believe anything this corrupt and easily offended media is trying to sale viewers.  Lastly, it’s ok the be an alpha male.  We life in a world where the media tries to treat grown men like infants
# Sentiment Scores: {'neg': 0.051, 'neu': 0.696, 'pos': 0.253, 'compound': 0.9597}
# BBs ys Descrimineit a man ,BBs whoate just meic money😮
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# What a dogshit interview, Tate has some so much shit, so much garbage, and yet she didn&#39;t manage to pin anything.<br>They could have prepared her better or at least include the quotes and sources such as the website in the folio, she spoke as if backed by rumors.
# Sentiment Scores: {'neg': 0.073, 'neu': 0.815, 'pos': 0.112, 'compound': 0.0056}
# BBs Ys sou Satanic ,dhā man whoate just to du god,dod gagi,a man hu whoate to do god for people,Fac BBs
# Sentiment Scores: {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'compound': 0.2732}
# The full interview is 38 minutes, where is rest of the time. An BBC is like the German public brodcast, where you are forced to pay for rubbish. An this creates arrogant, stupid reporters who think they own the truth and they have the authority to rule people. Discusting.
# Sentiment Scores: {'neg': 0.182, 'neu': 0.678, 'pos': 0.14, 'compound': -0.5461}
# Shame on you bbc
# Sentiment Scores: {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767}
# Imagine people like tate are being interviewed in such manner by news agencies to portray him as a negative man, what if common people like us will be there at place of tate
# Sentiment Scores: {'neg': 0.098, 'neu': 0.769, 'pos': 0.133, 'compound': 0.0772}
# Kingggg shittttt
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Ain&#39;t so hard to become a journalist at BBC, it seems. No preparation, no research, no numbers or real proof to back her statements, ridiculous.
# Sentiment Scores: {'neg': 0.362, 'neu': 0.638, 'pos': 0.0, 'compound': -0.8313}
# Andrew Tate 💪🏻😁
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 😂😂😂😂 bbc just sucks good in  😂😂😂 😂 cutting the clips 😂😂😂😂 WTF 😂😂😂😂
# Sentiment Scores: {'neg': 0.418, 'neu': 0.44, 'pos': 0.142, 'compound': -0.6841}
# King tate❤
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# he ist the boss
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Im from russia and videos of Andrew Tate were very inspirational for me, it affected very good on my life. We need men like him!
# Sentiment Scores: {'neg': 0.05, 'neu': 0.653, 'pos': 0.298, 'compound': 0.8393}
# Poor Lucy…. She failed at pushing her demonic agenda
# Sentiment Scores: {'neg': 0.478, 'neu': 0.522, 'pos': 0.0, 'compound': -0.7506}
# common L from bbc
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Wtv happened free speech ?!
# Sentiment Scores: {'neg': 0.0, 'neu': 0.527, 'pos': 0.473, 'compound': 0.5562}
# BBC and most other news network are absolute rubbish. They paint people and the world as they like but mostly impact our lives negatively. Stopped watching these clowns years ago and only watched this to see how they would cut the interview in their favour. Let’s just say it was an absolute train wreck. Great job Lucy you dressed for the occasion too, funeral of the BBC.
# Sentiment Scores: {'neg': 0.145, 'neu': 0.72, 'pos': 0.135, 'compound': 0.0387}
# You will notice if you watch the full video of this interview that she looks like a NPC in a game operated by an algorithm. She has no emotions. Just ask him what she got input.
# Sentiment Scores: {'neg': 0.06, 'neu': 0.872, 'pos': 0.068, 'compound': 0.0772}
# He was not 100% clean but now he has interesse in Islam they want destroy him. <br>Then he was just casual non believer .
# Sentiment Scores: {'neg': 0.22, 'neu': 0.655, 'pos': 0.126, 'compound': -0.576}
# Lucy you made a fool of yourself
# Sentiment Scores: {'neg': 0.367, 'neu': 0.633, 'pos': 0.0, 'compound': -0.4404}
# You failed, exposing the mainstream media once again
# Sentiment Scores: {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'compound': -0.6597}
# <a href="https://www.youtube.com/watch?v=h-JBhQqqWHY&amp;t=9m57s">9:57</a>  tell this woman to shush honestly
# Sentiment Scores: {'neg': 0.0, 'neu': 0.7, 'pos': 0.3, 'compound': 0.4588}
# Tate wasn’t challenged, he made Lucy look like an unprepared amateur who wasn’t willing to have a 2 way conversation with someone that was very hospitable and without Andrew Tate here this Lucy person is irrelevant
# Sentiment Scores: {'neg': 0.039, 'neu': 0.891, 'pos': 0.07, 'compound': 0.2732}
# Tate is king
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Andrew what I&#39;ve seen is, now not a clip from a interview that&#39;s taking out of context or fabricated or exaggerated. Andrew does preach discipline and healthy masculinity like the hero fireman that runs heroically in to a burning building to save life&#39;s police that protect your lifes an preaches religion no 1 is perfect but 1 man and his brother ain&#39;t the worlds problems
# Sentiment Scores: {'neg': 0.09, 'neu': 0.707, 'pos': 0.203, 'compound': 0.7184}
# only manosphere redpillers in the comments. zombies of the manosphere.. ignore the comments please
# Sentiment Scores: {'neg': 0.149, 'neu': 0.714, 'pos': 0.137, 'compound': -0.0516}
# It was embarassing how unprepared and just bad the reporter was. <br>What a shame. Worst interview ever by a reporter
# Sentiment Scores: {'neg': 0.416, 'neu': 0.584, 'pos': 0.0, 'compound': -0.8934}
# Watched full interview then watched this, the way they have cut the clips are illegitimate, and that absolute demonic gremlin of a woman PROBABLY doesn&#39;t deserve to live, not that I&#39;m the judge,  BECAUSE she is a deceptive liar, much like &#39;demonic&#39; forces historically. Hillary Clinton would be proud xD<br><br>That being said Andrew Tate probably does manipulate women to his advantage, BUT women manipulate men as well. Literally the human experience IS manipulating each other and ideally in a positive way. Encouraging children to study IS MANIPULATION, manipulation has positive contexts and literally people are either too short sighted, or to stupid, to even understand the world much like anyone who takes BBC seriously. Thank you
# Sentiment Scores: {'neg': 0.136, 'neu': 0.645, 'pos': 0.219, 'compound': 0.9224}
# Trying to frame tate
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# In fairness to the interviewer, he is not answering questions and denying things that he has actually said.
# Sentiment Scores: {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'compound': -0.34}
# BBC tried their best to shape him a bad person but horribly failed. I have watched full interview without any editing 😂. Shame on bbc. Andrew is genuinely is a genius person 😂😂.
# Sentiment Scores: {'neg': 0.359, 'neu': 0.581, 'pos': 0.06, 'compound': -0.9306}
# BBC still has control over the general people as even my parents are brainwashed into what the TV news channels portrays. Such BS
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# stupid questioning
# Sentiment Scores: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5859}
# She&#39;s a feminist
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Misleading and misrepresenting, whilst grooming our youth to instill mob mentality towards whoever disagrees with their ideology.. deplorable <a href="http://www.youtube.com/results?search_query=%23fatdislike">#FATDISLIKE</a>
# Sentiment Scores: {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.6124}
# BBC News are just a bunch of clowns
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Omg is this bbc ?!!
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# If you wanna see more, hit the dislike button for more lies😂😂😂
# Sentiment Scores: {'neg': 0.207, 'neu': 0.793, 'pos': 0.0, 'compound': -0.4336}
# Fake news ✋
# Sentiment Scores: {'neg': 0.756, 'neu': 0.244, 'pos': 0.0, 'compound': -0.4767}
# Propoganda channel
# Sentiment Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# if men are mysoginistic its not because of andrew but bc of dried up karens like lucy
# Sentiment Scores: {'neg': 0.0, 'neu': 0.831, 'pos': 0.169, 'compound': 0.5023}
# I am erasing BBC after this disingenuous attempt at pushing a narrative. Shame on BBC
# Sentiment Scores: {'neg': 0.205, 'neu': 0.795, 'pos': 0.0, 'compound': -0.4767}
# Andrew the best 🔱
# Sentiment Scores: {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}
# Still trying to push a negative narrative
# Sentiment Scores: {'neg': 0.425, 'neu': 0.575, 'pos': 0.0, 'compound': -0.5719}
# Hey guys why you so many have pressed like button instead of dislike button?!!!!<br>This interview is absolutely garbage😂😂😂
# Sentiment Scores: {'neg': 0.169, 'neu': 0.719, 'pos': 0.112, 'compound': -0.3111}
# Lucy wiliamson, she was broke,,, lol
# Sentiment Scores: {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.4215}
# Even the BBC&#39;s cut interview doesnt hit the mark in trying to smear him.  Im not a huge fan of AT, but he inherited his faathers chess skills. Checkmate
# Sentiment Scores: {'neg': 0.207, 'neu': 0.793, 'pos': 0.0, 'compound': -0.5043}
# R.I.P BBC A total failure 😂😂
# Sentiment Scores: {'neg': 0.452, 'neu': 0.548, 'pos': 0.0, 'compound': -0.5106}
# Actually you don’t get it you all if he’s manipulating he’s manipulating positively I dare ya do the same 🤣🤣🤣
# Sentiment Scores: {'neg': 0.205, 'neu': 0.656, 'pos': 0.139, 'compound': -0.1531}

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/furqaankhan/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Load the CSV file with comments
df = pd.read_csv('/Users/furqaankhan/Desktop/youtube_comments.csv')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Perform sentiment analysis for each comment
compound_scores = []
for comment in df['Comments']:
    sentiment_scores = analyzer.polarity_scores(comment)
    compound_scores.append(sentiment_scores['compound'])

# Create a histogram of the compound scores
plt.hist(compound_scores, bins=20, range=(-1, 1), edgecolor='black')
plt.xlabel('Sentiment Compound Score')
plt.ylabel('Frequency')
plt.title('Sentiment Analysis Histogram')
plt.show()

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Load the CSV file with comments
df = pd.read_csv('/Users/furqaankhan/Desktop/youtube_comments.csv')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Lists to store sentiment scores
neg_scores = []
neu_scores = []
pos_scores = []
compound_scores = []

# Perform sentiment analysis for each comment
for comment in df['Comments']:
    sentiment_scores = analyzer.polarity_scores(comment)
    neg_scores.append(sentiment_scores['neg'])
    neu_scores.append(sentiment_scores['neu'])
    pos_scores.append(sentiment_scores['pos'])
    compound_scores.append(sentiment_scores['compound'])

# Create histograms for each sentiment score
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Sentiment Analysis Histograms')

axes[0, 0].hist(neg_scores, bins=20, range=(0, 1), color='red', edgecolor='black')
axes[0, 0].set_title('Negative Score')
axes[0, 0].set_xlabel('Negative Score')
axes[0, 0].set_ylabel('Frequency')

axes[0, 1].hist(neu_scores, bins=20, range=(0, 1), color='gray', edgecolor='black')
axes[0, 1].set_title('Neutral Score')
axes[0, 1].set_xlabel('Neutral Score')
axes[0, 1].set_ylabel('Frequency')

axes[1, 0].hist(pos_scores, bins=20, range=(0, 1), color='green', edgecolor='black')
axes[1, 0].set_title('Positive Score')
axes[1, 0].set_xlabel('Positive Score')
axes[1, 0].set_ylabel('Frequency')

axes[1, 1].hist(compound_scores, bins=20, range=(-1, 1), color='blue', edgecolor='black')
axes[1, 1].set_title('Compound Score')
axes[1, 1].set_xlabel('Compound Score')
axes[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Load the CSV file with comments
df = pd.read_csv('/Users/furqaankhan/Desktop/youtube_comments.csv')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Calculate average sentiment scores for each category
total_comments = len(df)
average_sentiment = {
    'negative': sum(df['Comments'].apply(lambda comment: analyzer.polarity_scores(comment)['neg'])) / total_comments,
    'neutral': sum(df['Comments'].apply(lambda comment: analyzer.polarity_scores(comment)['neu'])) / total_comments,
    'positive': sum(df['Comments'].apply(lambda comment: analyzer.polarity_scores(comment)['pos'])) / total_comments,
}

# Create a bar plot to visualize the average sentiment scores
plt.bar(average_sentiment.keys(), average_sentiment.values(), color=['red', 'gray', 'green'])
plt.xlabel('Sentiment Category')
plt.ylabel('Average Score')
plt.title('Average Sentiment of Comment Section')
plt.show()

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Load the CSV file with comments
df = pd.read_csv('/Users/furqaankhan/Desktop/youtube_comments.csv')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Calculate average sentiment scores for each category
total_comments = len(df)
average_sentiment = {
    'negative': sum(df['Comments'].apply(lambda comment: analyzer.polarity_scores(comment)['neg'])) / total_comments,
    'neutral': sum(df['Comments'].apply(lambda comment: analyzer.polarity_scores(comment)['neu'])) / total_comments,
    'positive': sum(df['Comments'].apply(lambda comment: analyzer.polarity_scores(comment)['pos'])) / total_comments,
}

# Create a pie chart to visualize the sentiment distribution
labels = ['Negative', 'Neutral', 'Positive']
sizes = [average_sentiment['negative'], average_sentiment['neutral'], average_sentiment['positive']]
colors = ['red', 'gray', 'green']
explode = (0.1, 0, 0)  # To emphasize the 'Negative' slice

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Sentiment Distribution of YouTube Comments')
plt.show()

# %%
words = pd.read_csv("/Users/furqaankhan/Desktop/word_frequencies.csv")

# %%
words.head()
# Out:
#           Word  Frequency
# 0          BBC       4582
# 1            s       1217
# 2    interview       1136
# 3  Andrew Tate        976
# 4       Andrew        856

# %%
words.tail()
# Out:
#          Word  Frequency
# 10798  stolen          1
# 10799    cun7          1
# 10800   b1tch          1
# 10801  uglier          1
# 10802  peados          1
